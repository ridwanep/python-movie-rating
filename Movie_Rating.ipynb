# %% [markdown]
# <a href="https://colab.research.google.com/github/ridwanep/python-movie-rating/blob/main/Movie_Rating.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/1DS9TEdV6Y1A0xvs1Hq2nmJ-MSayAV9UoLeElQpBCwhU/edit#gid=973228725'
url_1 = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

movie = pd.read_csv(url_1, delimiter = '::')
movie.info()
movie.head()
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37341 entries, 0 to 37340
# Data columns (total 3 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   0000008                                        37341 non-null  int64
#  1   Edison Kinetoscopic Record of a Sneeze (1894)  37341 non-null  object
#  2   Documentary|Short,,,                           37341 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 875.3+ KB
#    0000008      Edison Kinetoscopic Record of a Sneeze (1894)  \
# ...

# %%
# Memberi nama kolom movie
movie.columns = ['ID', 'Title', 'Genre']
movie.info()
movie.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37341 entries, 0 to 37340
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      37341 non-null  int64
#  1   Title   37341 non-null  object
#  2   Genre   37341 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 875.3+ KB
#     ID                                              Title  \
# 0   10                La sortie des usines Lumière (1895)
# 1   12                      The Arrival of a Train (1896)
# 2   25  The Oxford and Cambridge University Boat Race ...
# 3   91                         Le manoir du diable (1896)
# 4  131                           Une nuit terrible (1896)
#
#                     Genre
# 0    Documentary|Short,,,
# 1    Documentary|Short,,,
# 2                     ,,,
# 3         Short|Horror,,,
# 4  Short|Comedy|Horror,,,

# %%
sheet_url2 = 'https://docs.google.com/spreadsheets/d/1JM7neTdTxjvwBCvsys8S-kkWbflMLaFtwOG3Zux2CU4/edit#gid=1687699209'
url_2 = sheet_url2.replace('/edit#gid=', '/export?format=csv&gid=')

rating = pd.read_csv(url_2, delimiter = '::')
rating.info()
rating.head()
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 906830 entries, 0 to 906829
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   1           906830 non-null  int64
#  1   0114508     906830 non-null  int64
#  2   8           906830 non-null  int64
#  3   1381006850  906830 non-null  int64
# dtypes: int64(4)
# memory usage: 27.7 MB
#    1  0114508  8  1381006850
# 0  2   499549  9  1376753198
# 1  2  1305591  8  1376742507
# 2  2  1428538  1  1371307089
# 3  3    75314  1  1595468524
# 4  3   102926  9  1590148016

# %%
rating.columns = ['User', 'ID', 'Ratings', 'Timestamp']
rating.info()
rating.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 906830 entries, 0 to 906829
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   User       906830 non-null  int64
#  1   ID         906830 non-null  int64
#  2   Ratings    906830 non-null  int64
#  3   Timestamp  906830 non-null  int64
# dtypes: int64(4)
# memory usage: 27.7 MB
#    User       ID  Ratings   Timestamp
# 0     2   499549        9  1376753198
# 1     2  1305591        8  1376742507
# 2     2  1428538        1  1371307089
# 3     3    75314        1  1595468524
# 4     3   102926        9  1590148016

# %%
# Menggabungkan data movie dan rating
df = pd.merge(movie, rating, on=['ID', 'ID'])
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 908632 entries, 0 to 908631
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   ID         908632 non-null  int64
#  1   Title      908632 non-null  object
#  2   Genre      908632 non-null  object
#  3   User       908632 non-null  int64
#  4   Ratings    908632 non-null  int64
#  5   Timestamp  908632 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 48.5+ MB
#    ID                                              Title  \
# 0  10                La sortie des usines Lumière (1895)
# 1  12                      The Arrival of a Train (1896)
# 2  25  The Oxford and Cambridge University Boat Race ...
# 3  91                         Le manoir du diable (1896)
# 4  91                         Le manoir du diable (1896)
#
#                   Genre   User  Ratings   Timestamp
# 0  Documentary|Short,,,  70577       10  1412878553
# ...

# %%
ratings = df['Ratings'].value_counts()
df['Ratings'].value_counts()
# Out:
# 8     219311
# 7     203476
# 9     128749
# 6     118323
# 10    107284
# 5      68458
# 4      27779
# 3      15258
# 1      10663
# 2       9053
# 0        278
# Name: Ratings, dtype: int64

# %%
ratings = df["Ratings"].value_counts()
numbers = ratings.index
quantity = ratings.values
import plotly.express as px
fig = px.pie(df, values=quantity, names=numbers)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
numbers = ratings.index
quantity = ratings.values
# df.plot(kind = 'pie',x=quantity, y=numbers)
plt.pie(quantity, labels = numbers)
plt.legend(title = 'Nilai Rating')
plt.show()

# %% [markdown]
# So, according to the pie chart above, most movies are rated 8 by users. From the above figure, it can be said that most of the movies are rated positively.

# %%
# Top 10 movies got 10 ratings by viewers
df2 = df.query('Ratings == 10')
df2['Title'].value_counts().head(10)
# Out:
# Joker (2019)                       1479
# Interstellar (2014)                1386
# 1917 (2019)                         820
# Avengers: Endgame (2019)            812
# The Shawshank Redemption (1994)     707
# Gravity (2013)                      653
# The Wolf of Wall Street (2013)      581
# Hacksaw Ridge (2016)                570
# Avengers: Infinity War (2018)       535
# La La Land (2016)                   510
# Name: Title, dtype: int64

# %% [markdown]
# So, according to this dataset, Joker (2019) got the highest number of 10 ratings from viewers.**bold text**
